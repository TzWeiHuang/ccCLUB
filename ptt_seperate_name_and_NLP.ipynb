# %%
import pandas as pd
df = pd.read_csv("ccClub_project_facebook.csv")

totle_lst = []
for i in range(50):
    messages = df.iloc[i,2]
    print(messages)
    
#     for j in messages_lst:
#         totle_lst.append()
# df.to_csv('facebook_messages.csv')
# Out:
# ['很好看', '好看👏好值得', '好帥喔', '好看', '哇，介绍给我', '很成功、自然', '很韓國風，很成功呢！', '自然又很帥耶😀', '好看~', '想知道哪一家\U0001f979', '請支持本版認證診所及醫師，在服務及責任也一份保障，目前歡迎參與討論，如透過討論是我們認證診所或醫師，可優先替您安排也能協助您爭取最佳服務，目前北區認證診所有知美、景升、雅丰、東京風采、諾美、元和雅、佳思優、立新、萊佳、教主、美朵、中山璀璨、欣莘、晶美、博恩妍、名悅、巨星、Aone、皇妍、賦真姸、艾尚美、恆麗、美渥館、美麗線、尚凌、群英、君綺、秀傳醫美...等診所\n桃竹苗區認證診所有990診所\n中區認證診所有風格、仙杜瑞拉、峻美、美朵、萊佳、教主、艾芙蘿、耀媄、群英...等診所\n南區認證診所有博愛民權萊佳、元和雅、雅典娜、健全曼哈頓、席睿、法喬、慈美、希拉雅、白璧、群英診所提供您參考\n\n一般會員請公開討論，非認證版主請勿私訊或商業推廣，如有違規請檢舉！以維護版內認證制度希望提供優質專業分享及服務...\n\n#醫美整形保養交流討論版\n\n醫美版將協助服務您的需求或問題，並能提供專屬隱密芳VIP服務、優先預約及最新訊息\n醫美版線上醫美秘書服務請加入\nhttps://lin.ee/A30RKzv', '請問在韓國那間醫生用的呢', '看也知道😂😂', '很好看', '好看', '这也太好看了吧😍', '', '帥！', '好看', 'Nico Chu沈妍羲']
# ...
